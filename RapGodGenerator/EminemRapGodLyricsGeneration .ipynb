fuck are you thinking?\nLittle gay-looking boy\nSo gay I can barely say it with a \'straight\' face, looking boy\nYou\'re witnessing a mass-occur like you\'re watching a church gathering take place, looking boy\nOy vey, that boy\'s gay\nThat\'s all they say, looking boy\nYou get a thumbs up, pat on the back\nAnd a "way to go" from your label every day, looking boy\nHey, looking boy, what d\'you say, looking boy?\nI get a "hell yeah" from Dre, looking boy\nI\'mma work for everything I have\nNever asked nobody for shit\nGet outta my face, looking boy\nBasically boy you\'re never gonna be capable\nOf keeping up with the same pace, looking boy, \'cause\n\nI\'m beginning to feel like a Rap God, Rap God\nAll my people from the front to the back nod, back nod\nThe way I\'m racing around the track, call me NASCAR, NASCAR\nDale Earnhardt of the trailer park, the White Trash God\nKneel before General Zod this planet\'s Krypton, no Asgard, Asgard\n\nSo you\'ll be Thor and I\'ll be Odin\nYou\'re rod ...

# %%
# Now removing punctuation and extra spaces 
import spacy 
import string 
nlp=spacy.load('en_core_web_sm',disable=['parser','ner','tagger'])

# %%
def remove_punc(text):
    
    return [token.text.lower() for token in nlp(text) if token.text not in set(string.punctuation) and token.text not in '\n\n \n\n\n!"-#$%&()--.*+,-/:;<=>?@[\\]^_`{|}~\t\n']

# %%
tokenized=remove_punc(my_file)
# Out:
# C:\Users\jaska\anaconda3\lib\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %%
tokenized
# Out:
# ['look',
#  'i',
#  'was',
#  'gon',
#  'na',
#  'go',
#  'easy',
#  'on',
#  'you',
#  'not',
#  'to',
#  'hurt',
#  'your',
#  'feelings',
#  'but',
#  'i',
#  "'m",
#  'only',
#  'going',
#  'to',
#  'get',
#  'this',
#  'one',
#  'chance',
#  'six',
#  'minutes',
#  'six',
#  'minutes',
#  'something',
#  "'s",
#  'wrong',
#  'i',
#  'can',
#  'feel',
#  'it',
#  'six',
#  'minutes',
#  'six',
#  'minutes',
#  'slim',
#  'shady',
#  'you',
#  "'re",
#  'on',
#  'just',
#  'a',
#  'feeling',
#  'i',
#  "'ve",
#  'got',
#  'like',
#  'something',
#  "'s",
#  'about',
#  'to',
#  'happen',
#  'but',
#  'i',
#  'do',
#  "n't",
#  'know',
#  'what',
#  'if',
#  'that',
#  'means',
#  'what',
#  'i',
#  'think',
#  'it',
#  'means',
#  'we',
#  "'re",
#  'in',
#  'trouble',
#  'big',
#  'trouble',
#  'and',
#  'if',
#  'he',
#  'is',
#  'as',
#  'bananas',
#  'as',
#  'you',
#  'say',
#  'i',
#  "'m",
#  'not',
#  'taking',
#  'any',
#  'chances',
#  'you',
#  'are',
#  'just',
#  'what',
#  'the',
#  'doc',
#  'ordered',
#  'i',
#  "'m",
#  'beginning',
#  'to',
#  'feel',
#  'like',
#  'a',
#  'rap',
#  'god',
#  'rap',
#  'god',
#  'all',
#  'my',
#  'people',
#  'from',
#  'the',
#  'front',
#  'to',
#  'the',
#  'back',
#  'nod',
#  'back',
#  'nod',
#  'now',
#  'who',
#  'thinks',
#  'their',
#  'arms',
#  'are',
#  'long',
#  'enough',
#  'to',
#  'slap',
#  'box',
#  'slap',
#  'box',
#  'they',
#  'said',
#  'i',
#  'rap',
#  'like',
#  'a',
#  'robot',
#  'so',
#  'call',
#  'me',
#  'rap',
#  'bot',
#  'but',
#  'for',
#  'me',
#  'to',
#  'rap',
#  'like',
#  'a',
#  'computer',
#  'must',
#  'be',
#  'in',
#  'my',
#  'genes',
#  'i',
#  'got',
#  'a',
#  'laptop',
#  'in',
#  'my',
#  'back',
#  'pocket',
#  'my',
#  "pen'll",
#  'go',
#  'off',
#  'when',
#  'i',
#  'half',
#  'cock',
#  'it',
#  'got',
#  'a',
#  'fat',
#  'knot',
#  'from',
#  'that',
#  'rap',
#  'profit',
#  'made',
#  'a',
#  'living',
#  'and',
#  'a',
#  'killing',
#  'off',
#  'it',
#  'ever',
#  'since',
#  'bill',
#  'clinton',
#  'was',
#  'still',
#  'in',
#  'office',
#  'with',
#  'monica',
#  'lewinsky',
#  'feeling',
#  'on',
#  'his',
#  'nutsack',
#  'i',
#  "'m",
#  'an',
#  'mc',
#  'still',
#  'as',
#  'honest',
#  'but',
#  'as',
#  'rude',
#  'and',
#  'as',
#  'indecent',
#  'as',
#  'all',
#  'hell',
#  'syllables',
#  'skill',
#  'a',
#  'holic',
#  'kill',
#  "'em",
#  'all',
#  'with',
#  'this',
#  'flippity',
#  'dippity',
#  'hippity',
#  'hip',
#  'hop',
#  'you',
#  'do',
#  "n't",
#  'really',
#  'wanna',
#  'get',
#  'into',
#  'a',
#  'pissing',
#  'match',
#  'with',
#  'this',
#  'rappity',
#  'brat',
#  'packing',
#  'a',
#  'mac',
#  'in',
#  'the',
#  'back',
#  'of',
#  'the',
#  'ac',
#  'backpack',
#  'rap',
#  'crap',
#  'yap',
#  'yap',
#  'yackety',
#  'yack',
#  'and',
#  'at',
#  'the',
#  'exact',
#  'same',
#  'time',
#  'i',
#  'attempt',
#  'these',
#  'lyrical',
#  'acrobat',
#  'stunts',
#  'while',
#  'i',
#  "'m",
#  'practicing',
#  'that',
#  'i',
#  "'ll",
#  'still',
#  'be',
#  'able',
#  'to',
#  'break',
#  'a',
#  'motherfuckin',
#  'table',
#  'over',
#  'the',
#  'back',
#  'of',
#  'a',
#  'couple',
#  'of',
#  'faggots',
#  'and',
#  'crack',
#  'it',
#  'in',
#  'half',
#  'only',
#  'realized',
#  'it',
#  'was',
#  'ironic',
#  'i',
#  'was',
#  'signed',
#  'to',
#  'aftermath',
#  'after',
#  'the',
#  'fact',
#  'how',
#  'could',
#  'i',
#  'not',
#  'blow',
#  'all',
#  'i',
#  'do',
#  'is',
#  'drop',
#  'f',
#  'bombs',
#  'feel',
#  'my',
#  'wrath',
#  'of',
#  'attack',
#  'rappers',
#  'are',
#  'having',
#  'a',
#  'rough',
#  'time',
#  'period',
#  'here',
#  "'s",
#  'a',
#  'maxi',
#  'pad',
#  'it',
#  "'s",
#  'actually',
#  'disastrously',
#  'bad',
#  'for',
#  'the',
#  'wack',
#  'while',
#  'i',
#  "'m",
#  'masterfully',
#  'constructing',
#  'this',
#  'masterpiece',
#  'yeah',
#  "'cause",
#  'i',
#  "'m",
#  'beginning',
#  'to',
#  'feel',
#  'like',
#  'a',
#  'rap',
#  'god',
#  'rap',
#  'god',
#  'all',
#  'my',
#  'people',
#  'from',
#  'the',
#  'front',
#  'to',
#  'the',
#  'back',
#  'nod',
#  'back',
#  'nod',
#  'now',
#  'who',
#  'thinks',
#  'their',
#  'arms',
#  'are',
#  'long',
#  'enough',
#  'to',
#  'slap',
#  'box',
#  'slap',
#  'box',
#  'let',
#  'me',
#  'show',
#  'you',
#  'maintaining',
#  'this',
#  'shit',
#  'ai',
#  "n't",
#  'that',
#  'hard',
#  'that',
#  'hard',
#  'everybody',
#  'want',
#  'the',
#  'key',
#  'and',
#  'the',
#  'secret',
#  'to',
#  'rap',
#  'immortality',
#  'like',
#  'i',
#  'have',
#  'got',
#  'well',
#  'to',
#  'be',
#  'truthful',
#  'the',
#  'blueprint',
#  "'s",
#  'simply',
#  'rage',
#  'and',
#  'youthful',
#  'exuberance',
#  'everybody',
#  'loves',
#  'to',
#  'root',
#  'for',
#  'a',
#  'nuisance',
#  'hit',
#  'the',
#  'earth',
#  'like',
#  'an',
#  'asteroid',
#  'did',
#  'nothing',
#  'but',
#  'shoot',
#  'for',
#  'the',
#  'moon',
#  'since',
#  'pew',
#  'mcs',
#  'get',
#  'taken',
#  'to',
#  'school',
#  'with',
#  'this',
#  'music',
#  "'cause",
#  'i',
#  'use',
#  'it',
#  'as',
#  'a',
#  'vehicle',
#  'to',
#  'bust',
#  'a',
#  'rhyme',
#  'now',
#  'i',
#  'lead',
#  'a',
#  'new',
#  'school',
#  'full',
#  'of',
#  'students',
#  'me',
#  'i',
#  "'m",
#  'a',
#  'product',
#  'of',
#  'rakim',
#  'lakim',
#  'shabazz',
#  '2pac',
#  'n.w.a.',
#  'cube',
#  'hey',
#  'doc',
#  'ren',
#  'yella',
#  'eazy',
#  'thank',
#  'you',
#  'they',
#  'got',
#  'slim',
#  'inspired',
#  'enough',
#  'to',
#  'one',
#  'day',
#  'grow',
#  'up',
#  'blow',
#  'up',
#  'and',
#  'be',
#  'in',
#  'a',
#  'position',
#  'to',
#  'meet',
#  'run',
#  'd.m.c.',
#  'and',
#  'induct',
#  'them',
#  'into',
#  'the',
#  'motherfuckin',
#  'rock',
#  'n',
#  'roll',
#  'hall',
#  'of',
#  'fame',
#  'even',
#  'though',
#  'i',
#  'walk',
#  'in',
#  'the',
#  'church',
#  'and',
#  'burst',
#  'in',
#  'a',
#  'ball',
#  'of',
#  'flames',
#  'only',
#  'hall',
#  'of',
#  'fame',
#  'i',
#  "'ll",
#  'be',
#  'inducted',
#  'in',
#  'is',
#  'the',
#  'alcohol',
#  'of',
#  'fame',
#  'on',
#  'the',
#  'wall',
#  'of',
#  'shame',
#  'you',
#  'fags',
#  'think',
#  'it',
#  "'s",
#  'all',
#  'a',
#  'game',
#  'til',
#  'i',
#  'walk',
#  'a',
#  'flock',
#  'of',
#  'flames',
#  'off',
#  'a',
#  'plank',
#  'and',
#  'tell',
#  'me',
#  'what',
#  'in',
#  'the',
#  'fuck',
#  'are',
#  'you',
#  'thinking',
#  'little',
#  'gay',
#  'looking',
#  'boy',
#  'so',
#  'gay',
#  'i',
#  'can',
#  'barely',
#  'say',
#  'it',
#  'with',
#  'a',
#  'straight',
#  'face',
#  'looking',
#  'boy',
#  'you',
#  "'re",
#  'witnessing',
#  'a',
#  'mass',
#  'occur',
#  'like',
#  'you',
#  "'re",
#  'watching',
#  'a',
#  'church',
#  'gathering',
#  'take',
#  'place',
#  'looking',
#  'boy',
#  'oy',
#  'vey',
#  'that',
#  'boy',
#  "'s",
#  'gay',
#  'that',
#  "'s",
#  'all',
#  'they',
#  'say',
#  'looking',
#  'boy',
#  'you',
#  'get',
#  'a',
#  'thumbs',
#  'up',
#  'pat',
#  'on',
#  'the',
#  'back',
#  'and',
#  'a',
#  'way',
#  'to',
#  'go',
#  'from',
#  'your',
#  'label',
#  'every',
#  'day',
#  'looking',
#  'boy',
#  'hey',
#  'looking',
#  'boy',
#  'what',
#  "d'you",
#  'say',
#  'looking',
#  'boy',
#  'i',
#  'get',
#  'a',
#  'hell',
#  'yeah',
#  'from',
#  'dre',
#  'looking',
#  'boy',
#  "i'mma",
#  'work',
#  'for',
#  'everything',
#  'i',
#  'have',
#  'never',
#  'asked',
#  'nobody',
#  'for',
#  'shit',
#  'get',
#  'outta',
#  'my',
#  'face',
#  'looking',
#  'boy',
#  'basically',
#  'boy',
#  'you',
#  "'re",
#  'never',
#  'gon',
#  'na',
#  'be',
#  'capable',
#  'of',
#  'keeping',
#  'up',
#  'with',
#  'the',
#  'same',
#  'pace',
#  'looking',
#  'boy',
#  "'cause",
#  'i',
#  "'m",
#  'beginning',
#  'to',
#  'feel',
#  'like',
#  'a',
#  'rap',
#  'god',
#  'rap',
#  'god',
#  'all',
#  'my',
#  'people',
#  'from',
#  'the',
#  'front',
#  'to',
#  'the',
#  'back',
#  'nod',
#  'back',
#  'nod',
#  'the',
#  'way',
#  'i',
#  "'m",
#  'racing',
#  'around',
#  'the',
#  'track',
#  'call',
#  'me',
#  'nascar',
#  'nascar',
#  'dale',
#  'earnhardt',
#  'of',
#  'the',
#  'trailer',
#  'park',
#  'the',
#  'white',
#  'trash',
#  'god',
#  'kneel',
#  'before',
#  'general',
#  'zod',
#  'this',
#  'planet',
#  "'s",
#  'krypton',
#  'no',
#  'asgard',
#  'asgard',
#  'so',
#  'you',
#  "'ll",
#  'be',
#  'thor',
#  'and',
#  'i',
#  "'ll",
#  'be',
#  'odin',
#  'you',
#  "'re",
#  'rodent',
#  'i',
#  "'m",
#  'omnipotent',
#  'let',
#  'off',
#  'then',
#  'i',
#  "'m",
#  'reloading',
#  'immediately',
#  'with',
#  'these',
#  'bombs',
#  'i',
#  "'m",
#  'totin',
#  'and',
#  'i',
#  'should',
#  'not',
#  'be',
#  'woken',
#  'i',
#  "'m",
#  'the',
#  'walking',
#  'dead',
#  'but',
#  'i',
#  "'m",
#  'just',
#  'a',
#  'talking',
#  'head',
#  'a',
#  'zombie',
#  'floating',
#  'but',
#  'i',
#  'got',
#  'your',
#  'mom',
#  'deep',
#  'throating',
#  'i',
#  "'m",
#  'out',
#  'my',
#  'ramen',
#  'noodle',
#  'we',
#  'have',
#  'nothing',
#  'in',
#  'common',
#  'poodle',
#  'i',
#  "'m",
#  'a',
#  'doberman',
#  'pinch',
#  'yourself',
#  'in',
#  'the',
#  'arm',
#  'and',
#  'pay',
#  'homage',
#  'pupil',
#  'it',
#  "'s",
#  'me',
#  'my',
#  'honesty',
#  "'s",
#  'brutal',
#  'but',
#  'it',
#  "'s",
#  'honestly',
#  'futile',
#  'if',
#  'i',
#  'do',
#  "n't",
#  'utilize',
#  'what',
#  'i',
#  'do',
#  'though',
#  'for',
#  'good',
#  'at',
#  'least',
#  'once',
#  'in',
#  'a',
#  'while',
#  'so',
#  'i',
#  'wanna',
#  'make',
#  'sure',
#  'somewhere',
#  'in',
#  'this',
#  'chicken',
#  'scratch',
#  'i',
#  'scribble',
#  'and',
#  'doodle',
#  'enough',
#  'rhymes',
#  'to',
#  'maybe',
#  'try',
#  'to',
#  'help',
#  'get',
#  'some',
#  'people',
#  'through',
#  'tough',
#  'times',
#  'but',
#  'i',
#  'got',
#  'ta',
#  'keep',
#  'a',
#  'few',
#  'punchlines',
#  'just',
#  'in',
#  'case',
#  "'cause",
#  'even',
#  'you',
#  'unsigned',
#  'rappers',
#  'are',
#  'hungry',
#  'looking',
#  'at',
#  'me',
#  'like',
#  'it',
#  "'s",
#  'lunchtime',
#  'i',
#  'know',
#  'there',
#  'was',
#  'a',
#  'time',
#  'where',
#  'once',
#  'i',
#  'was',
#  'king',
#  'of',
#  'the',
#  'underground',
#  'but',
#  'i',
#  'still',
#  'rap',
#  'like',
#  'i',
#  "'m",
#  'on',
#  'my',
#  'pharoahe',
#  'monch',
#  'grind',
#  'so',
#  'i',
#  'crunch',
#  'rhymes',
#  'but',
#  'sometimes',
#  'when',
#  'you',
#  'combine',
#  'appeal',
#  'with',
#  'the',
#  'skin',
#  'color',
#  'of',
#  'mine',
#  'you',
#  'get',
#  'too',
#  'big',
#  'and',
#  'here',
#  'they',
#  'come',
#  'trying',
#  'to',
#  'censor',
#  'you',
#  'like',
#  'that',
#  ...]

# %%
train_seq=26
sequences=[]

for i in range(train_seq,len(tokenized)):
    
    sentence=tokenized[i-train_seq:i]
    sequences.append(sentence)

# %%
sequences
# Out:
# [['look',
#   'i',
#   'was',
#   'gon',
#   'na',
#   'go',
#   'easy',
#   'on',
#   'you',
#   'not',
#   'to',
#   'hurt',
#   'your',
#   'feelings',
#   'but',
#   'i',
#   "'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes'],
#  ['i',
#   'was',
#   'gon',
#   'na',
#   'go',
#   'easy',
#   'on',
#   'you',
#   'not',
#   'to',
#   'hurt',
#   'your',
#   'feelings',
#   'but',
#   'i',
#   "'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six'],
#  ['was',
#   'gon',
#   'na',
#   'go',
#   'easy',
#   'on',
#   'you',
#   'not',
#   'to',
#   'hurt',
#   'your',
#   'feelings',
#   'but',
#   'i',
#   "'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes'],
#  ['gon',
#   'na',
#   'go',
#   'easy',
#   'on',
#   'you',
#   'not',
#   'to',
#   'hurt',
#   'your',
#   'feelings',
#   'but',
#   'i',
#   "'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something'],
#  ['na',
#   'go',
#   'easy',
#   'on',
#   'you',
#   'not',
#   'to',
#   'hurt',
#   'your',
#   'feelings',
#   'but',
#   'i',
#   "'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s"],
#  ['go',
#   'easy',
#   'on',
#   'you',
#   'not',
#   'to',
#   'hurt',
#   'your',
#   'feelings',
#   'but',
#   'i',
#   "'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong'],
#  ['easy',
#   'on',
#   'you',
#   'not',
#   'to',
#   'hurt',
#   'your',
#   'feelings',
#   'but',
#   'i',
#   "'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i'],
#  ['on',
#   'you',
#   'not',
#   'to',
#   'hurt',
#   'your',
#   'feelings',
#   'but',
#   'i',
#   "'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can'],
#  ['you',
#   'not',
#   'to',
#   'hurt',
#   'your',
#   'feelings',
#   'but',
#   'i',
#   "'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel'],
#  ['not',
#   'to',
#   'hurt',
#   'your',
#   'feelings',
#   'but',
#   'i',
#   "'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it'],
#  ['to',
#   'hurt',
#   'your',
#   'feelings',
#   'but',
#   'i',
#   "'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six'],
#  ['hurt',
#   'your',
#   'feelings',
#   'but',
#   'i',
#   "'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes'],
#  ['your',
#   'feelings',
#   'but',
#   'i',
#   "'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six'],
#  ['feelings',
#   'but',
#   'i',
#   "'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes'],
#  ['but',
#   'i',
#   "'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim'],
#  ['i',
#   "'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady'],
#  ["'m",
#   'only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you'],
#  ['only',
#   'going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re"],
#  ['going',
#   'to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on'],
#  ['to',
#   'get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just'],
#  ['get',
#   'this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a'],
#  ['this',
#   'one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling'],
#  ['one',
#   'chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i'],
#  ['chance',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve"],
#  ['six',
#   'minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got'],
#  ['minutes',
#   'six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like'],
#  ['six',
#   'minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something'],
#  ['minutes',
#   'something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s"],
#  ['something',
#   "'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about'],
#  ["'s",
#   'wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to'],
#  ['wrong',
#   'i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen'],
#  ['i',
#   'can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but'],
#  ['can',
#   'feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i'],
#  ['feel',
#   'it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do'],
#  ['it',
#   'six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't"],
#  ['six',
#   'minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know'],
#  ['minutes',
#   'six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what'],
#  ['six',
#   'minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if'],
#  ['minutes',
#   'slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that'],
#  ['slim',
#   'shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means'],
#  ['shady',
#   'you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what'],
#  ['you',
#   "'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i'],
#  ["'re",
#   'on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think'],
#  ['on',
#   'just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it'],
#  ['just',
#   'a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means'],
#  ['a',
#   'feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we'],
#  ['feeling',
#   'i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re"],
#  ['i',
#   "'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in'],
#  ["'ve",
#   'got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble'],
#  ['got',
#   'like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big'],
#  ['like',
#   'something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble'],
#  ['something',
#   "'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and'],
#  ["'s",
#   'about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if'],
#  ['about',
#   'to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he'],
#  ['to',
#   'happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is'],
#  ['happen',
#   'but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as'],
#  ['but',
#   'i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas'],
#  ['i',
#   'do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as'],
#  ['do',
#   "n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you'],
#  ["n't",
#   'know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say'],
#  ['know',
#   'what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i'],
#  ['what',
#   'if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m"],
#  ['if',
#   'that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not'],
#  ['that',
#   'means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking'],
#  ['means',
#   'what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any'],
#  ['what',
#   'i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances'],
#  ['i',
#   'think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you'],
#  ['think',
#   'it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are'],
#  ['it',
#   'means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just'],
#  ['means',
#   'we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what'],
#  ['we',
#   "'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the'],
#  ["'re",
#   'in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc'],
#  ['in',
#   'trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered'],
#  ['trouble',
#   'big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i'],
#  ['big',
#   'trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m"],
#  ['trouble',
#   'and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning'],
#  ['and',
#   'if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to'],
#  ['if',
#   'he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel'],
#  ['he',
#   'is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like'],
#  ['is',
#   'as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a'],
#  ['as',
#   'bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap'],
#  ['bananas',
#   'as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god'],
#  ['as',
#   'you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap'],
#  ['you',
#   'say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god'],
#  ['say',
#   'i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all'],
#  ['i',
#   "'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my'],
#  ["'m",
#   'not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people'],
#  ['not',
#   'taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from'],
#  ['taking',
#   'any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the'],
#  ['any',
#   'chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front'],
#  ['chances',
#   'you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to'],
#  ['you',
#   'are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the'],
#  ['are',
#   'just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back'],
#  ['just',
#   'what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod'],
#  ['what',
#   'the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back'],
#  ['the',
#   'doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod'],
#  ['doc',
#   'ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now'],
#  ['ordered',
#   'i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who'],
#  ['i',
#   "'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks'],
#  ["'m",
#   'beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their'],
#  ['beginning',
#   'to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms'],
#  ['to',
#   'feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are'],
#  ['feel',
#   'like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long'],
#  ['like',
#   'a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough'],
#  ['a',
#   'rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to'],
#  ['rap',
#   'god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap'],
#  ['god',
#   'rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box'],
#  ['rap',
#   'god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap'],
#  ['god',
#   'all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box'],
#  ['all',
#   'my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they'],
#  ['my',
#   'people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said'],
#  ['people',
#   'from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i'],
#  ['from',
#   'the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap'],
#  ['the',
#   'front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like'],
#  ['front',
#   'to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a'],
#  ['to',
#   'the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot'],
#  ['the',
#   'back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so'],
#  ['back',
#   'nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call'],
#  ['nod',
#   'back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me'],
#  ['back',
#   'nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap'],
#  ['nod',
#   'now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot'],
#  ['now',
#   'who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but'],
#  ['who',
#   'thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for'],
#  ['thinks',
#   'their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me'],
#  ['their',
#   'arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to'],
#  ['arms',
#   'are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap'],
#  ['are',
#   'long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like'],
#  ['long',
#   'enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a'],
#  ['enough',
#   'to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer'],
#  ['to',
#   'slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must'],
#  ['slap',
#   'box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be'],
#  ['box',
#   'slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in'],
#  ['slap',
#   'box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my'],
#  ['box',
#   'they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes'],
#  ['they',
#   'said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i'],
#  ['said',
#   'i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got'],
#  ['i',
#   'rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a'],
#  ['rap',
#   'like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop'],
#  ['like',
#   'a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in'],
#  ['a',
#   'robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my'],
#  ['robot',
#   'so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back'],
#  ['so',
#   'call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket'],
#  ['call',
#   'me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my'],
#  ['me',
#   'rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll"],
#  ['rap',
#   'bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go'],
#  ['bot',
#   'but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off'],
#  ['but',
#   'for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when'],
#  ['for',
#   'me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i'],
#  ['me',
#   'to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half'],
#  ['to',
#   'rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock'],
#  ['rap',
#   'like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it'],
#  ['like',
#   'a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got'],
#  ['a',
#   'computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a'],
#  ['computer',
#   'must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat'],
#  ['must',
#   'be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot'],
#  ['be',
#   'in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from'],
#  ['in',
#   'my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that'],
#  ['my',
#   'genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap'],
#  ['genes',
#   'i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit'],
#  ['i',
#   'got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made'],
#  ['got',
#   'a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a'],
#  ['a',
#   'laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living'],
#  ['laptop',
#   'in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and'],
#  ['in',
#   'my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a'],
#  ['my',
#   'back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing'],
#  ['back',
#   'pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off'],
#  ['pocket',
#   'my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it'],
#  ['my',
#   "pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever'],
#  ["pen'll",
#   'go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since'],
#  ['go',
#   'off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill'],
#  ['off',
#   'when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton'],
#  ['when',
#   'i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was'],
#  ['i',
#   'half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still'],
#  ['half',
#   'cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in'],
#  ['cock',
#   'it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office'],
#  ['it',
#   'got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with'],
#  ['got',
#   'a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica'],
#  ['a',
#   'fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica',
#   'lewinsky'],
#  ['fat',
#   'knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica',
#   'lewinsky',
#   'feeling'],
#  ['knot',
#   'from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica',
#   'lewinsky',
#   'feeling',
#   'on'],
#  ['from',
#   'that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica',
#   'lewinsky',
#   'feeling',
#   'on',
#   'his'],
#  ['that',
#   'rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica',
#   'lewinsky',
#   'feeling',
#   'on',
#   'his',
#   'nutsack'],
#  ['rap',
#   'profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica',
#   'lewinsky',
#   'feeling',
#   'on',
#   'his',
#   'nutsack',
#   'i'],
#  ['profit',
#   'made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica',
#   'lewinsky',
#   'feeling',
#   'on',
#   'his',
#   'nutsack',
#   'i',
#   "'m"],
#  ['made',
#   'a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica',
#   'lewinsky',
#   'feeling',
#   'on',
#   'his',
#   'nutsack',
#   'i',
#   "'m",
#   'an'],
#  ['a',
#   'living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica',
#   'lewinsky',
#   'feeling',
#   'on',
#   'his',
#   'nutsack',
#   'i',
#   "'m",
#   'an',
#   'mc'],
#  ['living',
#   'and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica',
#   'lewinsky',
#   'feeling',
#   'on',
#   'his',
#   'nutsack',
#   'i',
#   "'m",
#   'an',
#   'mc',
#   'still'],
#  ['and',
#   'a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica',
#   'lewinsky',
#   'feeling',
#   'on',
#   'his',
#   'nutsack',
#   'i',
#   "'m",
#   'an',
#   'mc',
#   'still',
#   'as'],
#  ['a',
#   'killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica',
#   'lewinsky',
#   'feeling',
#   'on',
#   'his',
#   'nutsack',
#   'i',
#   "'m",
#   'an',
#   'mc',
#   'still',
#   'as',
#   'honest'],
#  ['killing',
#   'off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica',
#   'lewinsky',
#   'feeling',
#   'on',
#   'his',
#   'nutsack',
#   'i',
#   "'m",
#   'an',
#   'mc',
#   'still',
#   'as',
#   'honest',
#   'but'],
#  ['off',
#   'it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica',
#   'lewinsky',
#   'feeling',
#   'on',
#   'his',
#   'nutsack',
#   'i',
#   "'m",
#   'an',
#   'mc',
#   'still',
#   'as',
#   'honest',
#   'but',
#   'as'],
#  ['it',
#   'ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica',
#   'lewinsky',
#   'feeling',
#   'on',
#   'his',
#   'nutsack',
#   'i',
#   "'m",
#   'an',
#   'mc',
#   'still',
#   'as',
#   'honest',
#   'but',
#   'as',
#   'rude'],
#  ['ever',
#   'since',
#   'bill',
#   'clinton',
#   'was',
#   'still',
#   'in',
#   'office',
#   'with',
#   'monica',
#   'lewinsky',
#   'feeling',
# ...
#   'still',
#   'rap'],
#  ['looking',
#   'at',
#   'me',
#   'like',
#   'it',
#   "'s",
#   'lunchtime',
#   'i',
#   'know',
#   'there',
#   'was',
#   'a',
#   'time',
#   'where',
#   'once',
#   'i',
#   'was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like'],
#  ['at',
#   'me',
#   'like',
#   'it',
#   "'s",
#   'lunchtime',
#   'i',
#   'know',
#   'there',
#   'was',
#   'a',
#   'time',
#   'where',
#   'once',
#   'i',
#   'was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i'],
#  ['me',
#   'like',
#   'it',
#   "'s",
#   'lunchtime',
#   'i',
#   'know',
#   'there',
#   'was',
#   'a',
#   'time',
#   'where',
#   'once',
#   'i',
#   'was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m"],
#  ['like',
#   'it',
#   "'s",
#   'lunchtime',
#   'i',
#   'know',
#   'there',
#   'was',
#   'a',
#   'time',
#   'where',
#   'once',
#   'i',
#   'was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on'],
#  ['it',
#   "'s",
#   'lunchtime',
#   'i',
#   'know',
#   'there',
#   'was',
#   'a',
#   'time',
#   'where',
#   'once',
#   'i',
#   'was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my'],
#  ["'s",
#   'lunchtime',
#   'i',
#   'know',
#   'there',
#   'was',
#   'a',
#   'time',
#   'where',
#   'once',
#   'i',
#   'was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe'],
#  ['lunchtime',
#   'i',
#   'know',
#   'there',
#   'was',
#   'a',
#   'time',
#   'where',
#   'once',
#   'i',
#   'was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch'],
#  ['i',
#   'know',
#   'there',
#   'was',
#   'a',
#   'time',
#   'where',
#   'once',
#   'i',
#   'was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind'],
#  ['know',
#   'there',
#   'was',
#   'a',
#   'time',
#   'where',
#   'once',
#   'i',
#   'was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so'],
#  ['there',
#   'was',
#   'a',
#   'time',
#   'where',
#   'once',
#   'i',
#   'was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i'],
#  ['was',
#   'a',
#   'time',
#   'where',
#   'once',
#   'i',
#   'was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch'],
#  ['a',
#   'time',
#   'where',
#   'once',
#   'i',
#   'was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes'],
#  ['time',
#   'where',
#   'once',
#   'i',
#   'was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but'],
#  ['where',
#   'once',
#   'i',
#   'was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes'],
#  ['once',
#   'i',
#   'was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when'],
#  ['i',
#   'was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you'],
#  ['was',
#   'king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine'],
#  ['king',
#   'of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal'],
#  ['of',
#   'the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with'],
#  ['the',
#   'underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the'],
#  ['underground',
#   'but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin'],
#  ['but',
#   'i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color'],
#  ['i',
#   'still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of'],
#  ['still',
#   'rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine'],
#  ['rap',
#   'like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you'],
#  ['like',
#   'i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get'],
#  ['i',
#   "'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too'],
#  ["'m",
#   'on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big'],
#  ['on',
#   'my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and'],
#  ['my',
#   'pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here'],
#  ['pharoahe',
#   'monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they'],
#  ['monch',
#   'grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come'],
#  ['grind',
#   'so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying'],
#  ['so',
#   'i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to'],
#  ['i',
#   'crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor'],
#  ['crunch',
#   'rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you'],
#  ['rhymes',
#   'but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like'],
#  ['but',
#   'sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that'],
#  ['sometimes',
#   'when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one'],
#  ['when',
#   'you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line'],
#  ['you',
#   'combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i'],
#  ['combine',
#   'appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said'],
#  ['appeal',
#   'with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on'],
#  ['with',
#   'the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i'],
#  ['the',
#   'skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m"],
#  ['skin',
#   'color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back'],
#  ['color',
#   'of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from'],
#  ['of',
#   'mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from',
#   'the'],
#  ['mine',
#   'you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from',
#   'the',
#   'mathers'],
#  ['you',
#   'get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from',
#   'the',
#   'mathers',
#   'lp'],
#  ['get',
#   'too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from',
#   'the',
#   'mathers',
#   'lp',
#   'one'],
#  ['too',
#   'big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from',
#   'the',
#   'mathers',
#   'lp',
#   'one',
#   'when'],
#  ['big',
#   'and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from',
#   'the',
#   'mathers',
#   'lp',
#   'one',
#   'when',
#   'i'],
#  ['and',
#   'here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from',
#   'the',
#   'mathers',
#   'lp',
#   'one',
#   'when',
#   'i',
#   'tried'],
#  ['here',
#   'they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from',
#   'the',
#   'mathers',
#   'lp',
#   'one',
#   'when',
#   'i',
#   'tried',
#   'to'],
#  ['they',
#   'come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from',
#   'the',
#   'mathers',
#   'lp',
#   'one',
#   'when',
#   'i',
#   'tried',
#   'to',
#   'say'],
#  ['come',
#   'trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from',
#   'the',
#   'mathers',
#   'lp',
#   'one',
#   'when',
#   'i',
#   'tried',
#   'to',
#   'say',
#   'i'],
#  ['trying',
#   'to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from',
#   'the',
#   'mathers',
#   'lp',
#   'one',
#   'when',
#   'i',
#   'tried',
#   'to',
#   'say',
#   'i',
#   "'ll"],
#  ['to',
#   'censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from',
#   'the',
#   'mathers',
#   'lp',
#   'one',
#   'when',
#   'i',
#   'tried',
#   'to',
#   'say',
#   'i',
#   "'ll",
#   'take'],
#  ['censor',
#   'you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from',
#   'the',
#   'mathers',
#   'lp',
#   'one',
#   'when',
#   'i',
#   'tried',
#   'to',
#   'say',
#   'i',
#   "'ll",
#   'take',
#   'seven'],
#  ['you',
#   'like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from',
#   'the',
#   'mathers',
#   'lp',
#   'one',
#   'when',
#   'i',
#   'tried',
#   'to',
#   'say',
#   'i',
#   "'ll",
#   'take',
#   'seven',
#   'kids'],
#  ['like',
#   'that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from',
#   'the',
#   'mathers',
#   'lp',
#   'one',
#   'when',
#   'i',
#   'tried',
#   'to',
#   'say',
#   'i',
#   "'ll",
#   'take',
#   'seven',
#   'kids',
#   'from'],
#  ['that',
#   'one',
#   'line',
#   'i',
#   'said',
#   'on',
#   'i',
#   "'m",
#   'back',
#   'from',
#   'the',
#   'mathers',
#   'lp',
#   'one',
#   'when',
#   'i',
#   'tried',
#   'to',
#   'say',
#   'i',
#   "'ll",
#   'take',
#   'seven',
#   'kids',
#   'from',
#   'columbine'],
#  ...]

# %%
" ".join(sequences[0])
# Out:
# "look i was gon na go easy on you not to hurt your feelings but i 'm only going to get this one chance six minutes"

# %%
" ".join(sequences[50])
# Out:
# "like something 's about to happen but i do n't know what if that means what i think it means we 're in trouble big trouble"

# %%
" ".join(sequences[98])
# Out:
# "i 'm beginning to feel like a rap god rap god all my people from the front to the back nod back nod now who thinks"

# %%
import tensorflow.keras as keras 
from keras.preprocessing.text import Tokenizer
from tensorflow.keras import Sequential
from keras.layers import Dense,LSTM,Embedding
from tensorflow.keras.utils import to_categorical

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts(sequences)
sequences=tokenizer.texts_to_sequences(sequences)

# %%
vocab_size=len(tokenizer.word_counts)
vocab_size
# Out:
# 608

# %%
import numpy as np 
seq=np.array(sequences)

# %%
seq.shape
# Out:
# (1622, 26)

# %%
def create_model(vocab_size,seq_len):
    
    model=Sequential()
    model.add(Embedding(vocab_size, 25, input_length=seq_len))
    model.add(LSTM(150,return_sequences=True))
    model.add(LSTM(150))
    model.add(Dense(150,activation='relu'))
    model.add(Dense(vocab_size,activation='softmax'))
    
    model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
    
    model.summary()
    
    return model

# %%
X=seq[:,:-1]
Y=seq[:,-1]

# %%
y=to_categorical(Y,num_classes=vocab_size+1)

# %%
y.shape
# Out:
# (1622, 609)

# %%
seq_length=X.shape[1]
seq_length
# Out:
# 25

# %%
model=create_model(vocab_size+1,seq_length)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 25, 25)            15225
#
#  lstm_4 (LSTM)               (None, 25, 150)           105600
#
#  lstm_5 (LSTM)               (None, 150)               180600
#
#  dense_3 (Dense)             (None, 150)               22650
#
#  dense_4 (Dense)             (None, 609)               91959
#
# =================================================================
# Total params: 416,034
# Trainable params: 416,034
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X,y,epochs=300,batch_size=64)
# Out:
# Epoch 1/300
# 26/26 [==============================] - 3s 37ms/step - loss: 6.1883 - accuracy: 0.0259
# Epoch 2/300
# 26/26 [==============================] - 1s 36ms/step - loss: 5.6995 - accuracy: 0.0536
# Epoch 3/300
# 26/26 [==============================] - 1s 37ms/step - loss: 5.6208 - accuracy: 0.0487
# Epoch 4/300
# 26/26 [==============================] - 1s 39ms/step - loss: 5.5953 - accuracy: 0.0536
# Epoch 5/300
# 26/26 [==============================] - 1s 43ms/step - loss: 5.5884 - accuracy: 0.0536
# Epoch 6/300
# 26/26 [==============================] - 1s 39ms/step - loss: 5.5843 - accuracy: 0.0536
# Epoch 7/300
# 26/26 [==============================] - 1s 40ms/step - loss: 5.5820 - accuracy: 0.0536
# Epoch 8/300
# 26/26 [==============================] - 1s 40ms/step - loss: 5.5806 - accuracy: 0.0536
# Epoch 9/300
# 26/26 [==============================] - 1s 40ms/step - loss: 5.5771 - accuracy: 0.0536
# Epoch 10/300
300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.8252 - accuracy: 0.8224
# Epoch 71/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.8048 - accuracy: 0.8224
# Epoch 72/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.7492 - accuracy: 0.8434
# Epoch 73/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.7051 - accuracy: 0.8514
# Epoch 74/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.6851 - accuracy: 0.8594
# Epoch 75/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.6354 - accuracy: 0.8656
# Epoch 76/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.5938 - accuracy: 0.8896
# Epoch 77/300
# 26/26 [==============================] - 1s 46ms/step - loss: 0.5719 - accuracy: 0.8977
# Epoch 78/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.5202 - accuracy: 0.9118
# Epoch 79/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.4899 - accuracy: 0.9143
# Epoch 80/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.4593 - accuracy: 0.9223
# Epoch 81/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.4304 - accuracy: 0.9445
# Epoch 82/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.4117 - accuracy: 0.9408
# Epoch 83/300
# 26/26 [==============================] - 1s 46ms/step - loss: 0.3911 - accuracy: 0.9451
# Epoch 84/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.3537 - accuracy: 0.9568
# Epoch 85/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.3318 - accuracy: 0.9612
# Epoch 86/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.3061 - accuracy: 0.9636
# Epoch 87/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.2969 - accuracy: 0.9636
# Epoch 88/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.2682 - accuracy: 0.9710
# Epoch 89/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.2379 - accuracy: 0.9815
# Epoch 90/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.2274 - accuracy: 0.9827
# Epoch 91/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.2051 - accuracy: 0.9858
# Epoch 92/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.1882 - accuracy: 0.9889
# Epoch 93/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.1831 - accuracy: 0.9908
# Epoch 94/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.1782 - accuracy: 0.9889
# Epoch 95/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.1706 - accuracy: 0.9889
# Epoch 96/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.1528 - accuracy: 0.9920
# Epoch 97/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.1466 - accuracy: 0.9908
# Epoch 98/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.1522 - accuracy: 0.9920
# Epoch 99/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.1351 - accuracy: 0.9932
# Epoch 100/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.1183 - accuracy: 0.9951
# Epoch 101/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.1049 - accuracy: 0.9969
# Epoch 102/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0979 - accuracy: 0.9969
# Epoch 103/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0898 - accuracy: 0.9982
# Epoch 104/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0849 - accuracy: 0.9975
# Epoch 105/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0815 - accuracy: 0.9975
# Epoch 106/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0753 - accuracy: 0.9994
# Epoch 107/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0739 - accuracy: 0.9982
# Epoch 108/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0676 - accuracy: 0.9982
# Epoch 109/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0644 - accuracy: 0.9988
# Epoch 110/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0589 - accuracy: 0.9988
# Epoch 111/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0559 - accuracy: 0.9982
# Epoch 112/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0547 - accuracy: 0.9988
# Epoch 113/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0521 - accuracy: 0.9988
# Epoch 114/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0499 - accuracy: 0.9975
# Epoch 115/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0462 - accuracy: 0.9982
# Epoch 116/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0476 - accuracy: 0.9982
# Epoch 117/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0429 - accuracy: 0.9988
# Epoch 118/300
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0407 - accuracy: 0.9982
# Epoch 119/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0374 - accuracy: 0.9988
# Epoch 120/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0362 - accuracy: 0.9982
# Epoch 121/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0345 - accuracy: 0.9988
# Epoch 122/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0340 - accuracy: 0.9982
# Epoch 123/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0328 - accuracy: 0.9988
# Epoch 124/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0315 - accuracy: 0.9975
# Epoch 125/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0304 - accuracy: 0.9982
# Epoch 126/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0293 - accuracy: 0.9988
# Epoch 127/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0279 - accuracy: 0.9982
# Epoch 128/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0284 - accuracy: 0.9988
# Epoch 129/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0261 - accuracy: 0.9988
# Epoch 130/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0252 - accuracy: 0.9982
# Epoch 131/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0249 - accuracy: 0.9982
# Epoch 132/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0240 - accuracy: 0.9988
# Epoch 133/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0295 - accuracy: 0.9988
# Epoch 134/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0261 - accuracy: 0.9975
# Epoch 135/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0233 - accuracy: 0.9982
# Epoch 136/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0203 - accuracy: 0.9988
# Epoch 137/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0202 - accuracy: 0.9988
# Epoch 138/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0189 - accuracy: 0.9988
# Epoch 139/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0190 - accuracy: 0.9988
# Epoch 140/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0201 - accuracy: 0.9982
# Epoch 141/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0181 - accuracy: 0.9982
# Epoch 142/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0201 - accuracy: 0.9982
# Epoch 143/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0176 - accuracy: 0.9988
# Epoch 144/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0166 - accuracy: 0.9988
# Epoch 145/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0160 - accuracy: 0.9982
# Epoch 146/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0153 - accuracy: 0.9982
# Epoch 147/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0148 - accuracy: 0.9988
# Epoch 148/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0148 - accuracy: 0.9988
# Epoch 149/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0143 - accuracy: 0.9982
# Epoch 150/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0152 - accuracy: 0.9982
# Epoch 151/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0133 - accuracy: 0.9982
# Epoch 152/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0140 - accuracy: 0.9982
# Epoch 153/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0149 - accuracy: 0.9982
# Epoch 154/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0123 - accuracy: 0.9982
# Epoch 155/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0130 - accuracy: 0.9988
# Epoch 156/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0124 - accuracy: 0.9982
# Epoch 157/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0124 - accuracy: 0.9982
# Epoch 158/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0138 - accuracy: 0.9975
# Epoch 159/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0121 - accuracy: 0.9975
# Epoch 160/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0114 - accuracy: 0.9982
# Epoch 161/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0102 - accuracy: 0.9988
# Epoch 162/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0112 - accuracy: 0.9975
# Epoch 163/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0107 - accuracy: 0.9982
# Epoch 164/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0100 - accuracy: 0.9975
# Epoch 165/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0099 - accuracy: 0.9988
# Epoch 166/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0103 - accuracy: 0.9982
# Epoch 167/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0096 - accuracy: 0.9982
# Epoch 168/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0107 - accuracy: 0.9975
# Epoch 169/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0090 - accuracy: 0.9982
# Epoch 170/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0096 - accuracy: 0.9988
# Epoch 171/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0101 - accuracy: 0.9982
# Epoch 172/300
# 26/26 [==============================] - 1s 38ms/step - loss: 0.0086 - accuracy: 0.9988
# Epoch 173/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0096 - accuracy: 0.9982
# Epoch 174/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0095 - accuracy: 0.9988
# Epoch 175/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0082 - accuracy: 0.9988
# Epoch 176/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0097 - accuracy: 0.9988
# Epoch 177/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0091 - accuracy: 0.9975
# Epoch 178/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0109 - accuracy: 0.9988
# Epoch 179/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.2780 - accuracy: 0.9408
# Epoch 180/300
# 26/26 [==============================] - 1s 39ms/step - loss: 2.0746 - accuracy: 0.5197
# Epoch 181/300
# 26/26 [==============================] - 1s 40ms/step - loss: 1.3950 - accuracy: 0.6054
# Epoch 182/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.5813 - accuracy: 0.8181
# Epoch 183/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.2564 - accuracy: 0.9377
# Epoch 184/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.1144 - accuracy: 0.9858
# Epoch 185/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0590 - accuracy: 0.9975
# Epoch 186/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0365 - accuracy: 0.9982
# Epoch 187/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0277 - accuracy: 0.9975
# Epoch 188/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0238 - accuracy: 0.9982
# Epoch 189/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0224 - accuracy: 0.9982
# Epoch 190/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0209 - accuracy: 0.9975
# Epoch 191/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0184 - accuracy: 0.9988
# Epoch 192/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0177 - accuracy: 0.9975
# Epoch 193/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0167 - accuracy: 0.9988
# Epoch 194/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0156 - accuracy: 0.9982
# Epoch 195/300
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0153 - accuracy: 0.9982
# Epoch 196/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0148 - accuracy: 0.9982
# Epoch 197/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0161 - accuracy: 0.9988
# Epoch 198/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0146 - accuracy: 0.9988
# Epoch 199/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0125 - accuracy: 0.9988
# Epoch 200/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0126 - accuracy: 0.9988
# Epoch 201/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0122 - accuracy: 0.9988
# Epoch 202/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0124 - accuracy: 0.9982
# Epoch 203/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0122 - accuracy: 0.9982
# Epoch 204/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0111 - accuracy: 0.9982
# Epoch 205/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0112 - accuracy: 0.9982
# Epoch 206/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0121 - accuracy: 0.9982
# Epoch 207/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0105 - accuracy: 0.9982
# Epoch 208/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0099 - accuracy: 0.9988
# Epoch 209/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0104 - accuracy: 0.9975
# Epoch 210/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0101 - accuracy: 0.9975
# Epoch 211/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0095 - accuracy: 0.9982
# Epoch 212/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0103 - accuracy: 0.9988
# Epoch 213/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0086 - accuracy: 0.9994
# Epoch 214/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0111 - accuracy: 0.9988
# Epoch 215/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0093 - accuracy: 0.9982
# Epoch 216/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0092 - accuracy: 0.9975
# Epoch 217/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0087 - accuracy: 0.9988
# Epoch 218/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0089 - accuracy: 0.9982
# Epoch 219/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0081 - accuracy: 0.9982
# Epoch 220/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0079 - accuracy: 0.9988
# Epoch 221/300
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0080 - accuracy: 0.9988
# Epoch 222/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0086 - accuracy: 0.9982
# Epoch 223/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0078 - accuracy: 0.9988
# Epoch 224/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0078 - accuracy: 0.9975
# Epoch 225/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0089 - accuracy: 0.9982
# Epoch 226/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0072 - accuracy: 0.9982
# Epoch 227/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0077 - accuracy: 0.9982
# Epoch 228/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0073 - accuracy: 0.9975
# Epoch 229/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0072 - accuracy: 0.9982
# Epoch 230/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0071 - accuracy: 0.9982
# Epoch 231/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0075 - accuracy: 0.9982
# Epoch 232/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0066 - accuracy: 0.9988
# Epoch 233/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0071 - accuracy: 0.9988
# Epoch 234/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0064 - accuracy: 0.9982
# Epoch 235/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0074 - accuracy: 0.9988
# Epoch 236/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0063 - accuracy: 0.9975
# Epoch 237/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0061 - accuracy: 0.9988
# Epoch 238/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0063 - accuracy: 0.9982
# Epoch 239/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0071 - accuracy: 0.9975
# Epoch 240/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0063 - accuracy: 0.9988
# Epoch 241/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0069 - accuracy: 0.9975
# Epoch 242/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0064 - accuracy: 0.9982
# Epoch 243/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0078 - accuracy: 0.9988
# Epoch 244/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0061 - accuracy: 0.9988
# Epoch 245/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0059 - accuracy: 0.9982
# Epoch 246/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0055 - accuracy: 0.9982
# Epoch 247/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0063 - accuracy: 0.9982
# Epoch 248/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0059 - accuracy: 0.9982
# Epoch 249/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0058 - accuracy: 0.9975
# Epoch 250/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0059 - accuracy: 0.9988
# Epoch 251/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0048 - accuracy: 0.9988
# Epoch 252/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0062 - accuracy: 0.9982
# Epoch 253/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0057 - accuracy: 0.9988
# Epoch 254/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0057 - accuracy: 0.9975
# Epoch 255/300
# 26/26 [==============================] - 1s 39ms/step - loss: 0.0056 - accuracy: 0.9982
# Epoch 256/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0070 - accuracy: 0.9994
# Epoch 257/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0092 - accuracy: 0.9988
# Epoch 258/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0050 - accuracy: 0.9988
# Epoch 259/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0059 - accuracy: 0.9975
# Epoch 260/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0056 - accuracy: 0.9988
# Epoch 261/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0053 - accuracy: 0.9982
# Epoch 262/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0056 - accuracy: 0.9982
# Epoch 263/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0048 - accuracy: 0.9982
# Epoch 264/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0040 - accuracy: 0.9988
# Epoch 265/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0060 - accuracy: 0.9988
# Epoch 266/300
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0064 - accuracy: 0.9982
# Epoch 267/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0054 - accuracy: 0.9982
# Epoch 268/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0054 - accuracy: 0.9975
# Epoch 269/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0051 - accuracy: 0.9988
# Epoch 270/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0049 - accuracy: 0.9988
# Epoch 271/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0044 - accuracy: 0.9994
# Epoch 272/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0056 - accuracy: 0.9988
# Epoch 273/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0108 - accuracy: 0.9982
# Epoch 274/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0137 - accuracy: 0.9975
# Epoch 275/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0159 - accuracy: 0.9975
# Epoch 276/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.1012 - accuracy: 0.9723
# Epoch 277/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.6043 - accuracy: 0.8243
# Epoch 278/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.9756 - accuracy: 0.7207
# Epoch 279/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.5767 - accuracy: 0.8237
# Epoch 280/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.2279 - accuracy: 0.9340
# Epoch 281/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0862 - accuracy: 0.9803
# Epoch 282/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0378 - accuracy: 0.9926
# Epoch 283/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0253 - accuracy: 0.9969
# Epoch 284/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0148 - accuracy: 0.9982
# Epoch 285/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0105 - accuracy: 0.9988
# Epoch 286/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0090 - accuracy: 0.9988
# Epoch 287/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0090 - accuracy: 0.9975
# Epoch 288/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0081 - accuracy: 0.9975
# Epoch 289/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0077 - accuracy: 0.9982
# Epoch 290/300
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0076 - accuracy: 0.9982
# Epoch 291/300
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0075 - accuracy: 0.9982
# Epoch 292/300
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0073 - accuracy: 0.9988
# Epoch 293/300
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0070 - accuracy: 0.9988
# Epoch 294/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0093 - accuracy: 0.9982
# Epoch 295/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0069 - accuracy: 0.9982
# Epoch 296/300
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0058 - accuracy: 0.9988
# Epoch 297/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0063 - accuracy: 0.9988
# Epoch 298/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0061 - accuracy: 0.9975
# Epoch 299/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0062 - accuracy: 0.9988
# Epoch 300/300
# 26/26 [==============================] - 1s 40ms/step - loss: 0.0057 - accuracy: 0.9982

# %%
from keras.preprocessing.sequence import pad_sequences

# %%
# !pip install tensorflow==2.5.2
# Out:
# Collecting tensorflow==2.5.2
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 173, in _main
#     status = self.run(options, args)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 203, in wrapper
#     return func(self, options, args)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 315, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 94, in resolve
#     result = self._result = resolver.resolve(
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 472, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 341, in resolve
#     self._add_to_criteria(self.state.criteria, r, parent=None)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 172, in _add_to_criteria
#     if not criterion.candidates:
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 151, in __bool__
#     return bool(self._sequence)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 140, in __bool__
#     return any(self)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 128, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 32, in _iter_built
#     candidate = func()
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 204, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 295, in __init__
#     super().__init__(
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 227, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 305, in _prepare_distribution
#     return self._factory.preparer.prepare_linked_requirement(
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 508, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 550, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 239, in unpack_url
#     file = get_http_url(
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 102, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\network\download.py", line 132, in __call__
#     resp = _http_get_download(self._session, link)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\network\download.py", line 115, in _http_get_download
#     resp = session.get(target_url, headers=HEADERS, stream=True)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_vendor\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_internal\network\session.py", line 454, in request
#     return super().request(method, url, *args, **kwargs)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_vendor\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_vendor\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\adapter.py", line 44, in send
#     cached_response = self.controller.cached_request(request)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\controller.py", line 145, in cached_request
#     resp = self.serializer.loads(request, cache_data)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\serialize.py", line 97, in loads
#     return getattr(self, "_loads_v{}".format(ver))(request, data)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\serialize.py", line 184, in _loads_v4
#     cached = msgpack.loads(data, raw=False)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_vendor\msgpack\fallback.py", line 129, in unpackb
#     ret = unpacker._unpack()
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_vendor\msgpack\fallback.py", line 671, in _unpack
#     ret[key] = self._unpack(EX_CONSTRUCT)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_vendor\msgpack\fallback.py", line 671, in _unpack
#     ret[key] = self._unpack(EX_CONSTRUCT)
#   File "C:\Users\jaska\anaconda3\lib\site-packages\pip\_vendor\msgpack\fallback.py", line 684, in _unpack
#     return bytes(obj)
# MemoryError

# %%
def predict(model,tokenizer,seq_len,seed_text,num_gen_word):
    
    input_text=seed_text
    
    output_text=[]
    
    for i in range(num_gen_word):
        
        encoded_text=tokenizer.texts_to_sequences([input_text])[0]
        pad_encoded=pad_sequences([encoded_text],maxlen=seq_len,truncating='pre')
        
        pred_word_ind= model.predict(pad_encoded)[0]
        classes_x=np.argmax(pred_word_ind,axis=-1)
        pred_word=tokenizer.index_word[classes_x]
        
        input_text+=" "+pred_word
        output_text.append(pred_word)
        
    return " ".join(output_text)

# %%
predict(model,tokenizer,seq_length," ".join(sequences[10]),300)
# Out:
# "minutes six minutes slim shady you 're on just a feeling i 've got like something 's about to happen but i do n't know what if that means what i think it means we 're in trouble big trouble and if he is as bananas as you say i 'm not taking any chances you are just what the doc ordered i 'm beginning to feel like a rap god rap god all my people from the front to the back nod back nod now who thinks their arms are long enough to slap box slap box let me show you maintaining this shit ai n't that hard that hard everybody want the key and the secret to rap immortality like i have got well to be truthful the blueprint 's simply rage and youthful exuberance everybody loves to root for a nuisance hit the earth like an asteroid did nothing but shoot for the moon since pew mcs get taken to school with this music 'cause i use it as a vehicle to bust a rhyme now i lead a new school full of students me i 'm a product of rakim lakim shabazz 2pac n.w.a. uh summa lumma dooma lumma you assuming you 'll get get into with minutes slim key and the line and if i need to be overseas and 's angels ray gun be dre i 'm asleep in the front seat bumping heavy d and the nine still chunky but funky but in my head there 's something i can feel tugging and struggling angels fight with devils and here 's what they want from me they 're asking me to eliminate some of the women hate but if you take into consideration the bitter hatred i had then you may be a"

# %%
" ".join(sequences[0])
# Out:
# "look i was gon na go easy on you not to hurt your feelings but i 'm only going to get this one chance six minutes"

# %%
encoded_text=tokenizer.texts_to_sequences(" ".join(sequences[0]))[0]
pad_encoded=pad_sequences([encoded_text],maxlen=seq_length,truncating='pre')
        
pred_word_ind= model.predict(pad_encoded)[0]
pred_word_ind
# Out:
# array([2.66370684e-04, 1.55660064e-06, 1.69320738e-05, 1.92037805e-05,
#        9.47867306e-07, 5.81524375e-07, 1.45343793e-09, 1.12103837e-08,
#        1.55811009e-09, 3.62828811e-09, 5.54244980e-05, 9.70451719e-09,
#        9.36815013e-06, 3.81018150e-09, 8.98320862e-11, 4.26231636e-05,
#        1.17165830e-04, 4.29817376e-10, 1.16819427e-11, 1.85071000e-10,
#        9.25613102e-13, 4.39539690e-06, 5.93039658e-07, 1.75260819e-08,
#        5.83447502e-07, 4.65969009e-07, 2.75425932e-10, 3.21635464e-03,
#        4.24539084e-11, 5.94590801e-07, 3.28478222e-09, 8.41761660e-03,
#        9.40117985e-03, 1.49475895e-07, 2.58942810e-03, 3.03547694e-07,
#        6.20395269e-07, 3.43598425e-04, 3.33992631e-07, 1.50991600e-05,
#        2.20120583e-05, 9.05108024e-08, 7.42148476e-09, 5.78573199e-05,
#        6.97959767e-05, 9.27841370e-07, 5.91823573e-06, 1.54488716e-05,
#        6.11258565e-06, 6.30886524e-11, 2.17426149e-03, 1.25196375e-05,
#        1.29837954e-05, 7.38830124e-07, 3.16734261e-09, 6.90205559e-10,
#        2.77884382e-08, 8.05579984e-05, 1.30838189e-05, 8.09843186e-06,
#        7.12289989e-07, 1.60306672e-06, 5.10248992e-06, 8.50892502e-06,
#        6.32301544e-09, 6.37889102e-08, 2.25520736e-07, 1.64728693e-08,
#        3.09401837e-09, 2.36853037e-10, 4.75441848e-05, 1.70462998e-03,
#        4.75883638e-07, 2.35577894e-11, 5.72192027e-09, 1.14045171e-04,
#        9.86447257e-10, 1.39727199e-03, 5.65910767e-08, 7.93800427e-05,
#        1.43972454e-06, 1.11790648e-07, 6.51688623e-08, 2.65621318e-04,
#        2.76547174e-10, 1.86563324e-04, 6.34944945e-06, 9.04607930e-07,
#        9.26734600e-08, 4.58523708e-08, 1.94347052e-07, 9.11813700e-08,
#        4.07671646e-10, 2.46012746e-07, 4.14086651e-04, 2.71612421e-08,
#        8.97624233e-08, 2.38738971e-06, 8.00209747e-08, 8.55109654e-03,
#        4.08717113e-07, 4.17613683e-06, 3.79564558e-09, 4.60956665e-03,
#        3.64557048e-03, 7.20371872e-06, 7.71034502e-06, 3.86662471e-08,
#        2.09198383e-08, 3.64724384e-09, 4.33145537e-08, 1.27901867e-08,
#        1.35090086e-05, 7.60002692e-08, 4.08836611e-04, 6.09903291e-05,
#        4.71810296e-07, 6.47968118e-05, 5.85697017e-05, 8.68970808e-03,
#        2.15975344e-08, 4.53990658e-08, 3.99481657e-08, 1.49246357e-08,
#        4.87194484e-04, 5.76563242e-09, 2.60209367e-06, 1.54481269e-04,
#        3.12606130e-06, 2.73813839e-07, 1.89618120e-07, 1.54275121e-02,
#        5.70433052e-08, 7.03953265e-05, 7.98858132e-11, 1.80686968e-08,
#        9.91360048e-06, 4.49722214e-03, 1.04282999e-10, 4.50134687e-02,
#        1.75771007e-08, 1.75448222e-05, 1.90012894e-09, 9.71155474e-04,
#        4.70610807e-11, 1.51533050e-10, 1.24464222e-07, 8.10513754e-08,
#        5.43135226e-09, 2.03125235e-02, 7.00666973e-08, 1.51986140e-03,
#        3.35625668e-06, 6.66140615e-11, 6.55948045e-03, 4.35702603e-08,
#        6.85475767e-03, 1.24343162e-04, 5.07491586e-06, 2.94261030e-04,
#        1.62171535e-02, 2.01409697e-04, 1.47645813e-04, 3.66986740e-07,
#        3.20984022e-04], dtype=float32)

# %%
classes_x=np.argmax(pred_word_ind,axis=-1)

# %%
classes_x
# Out:
# 313

# %%
tokenizer.index_word[classes_x]
# Out:
# 'position'
